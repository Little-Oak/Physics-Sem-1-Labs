# %% [markdown]
# # Group (IDK WHAT NUMBER) Experiment 1 Code
# #### By: Jose Cabigon
# ![image.png](attachment:ec818fc4-ebc7-4ea5-bb98-a789cd98b76a.png)
#
# Hello! Please check below for all the code needed for the phyics lab experiment 1 for the group of Arreza, Cabigon, Fabular, Oracion, Polanco, and Sakata.
# Here is a table of functions needed:
# |      Function     |      Purpose      |
# |:------------------|:------------------------------|
# |Volume Calculation | Write a Python function that takes the measured dimensions of a block (length, width, height) and calculates the volume, including the propagated error.|
# |Percent Difference | Write a Python function that takes two sets of measurements (e.g., from the two trials) and calculates the percent difference between them.|
# |Density Calculation| Write a Python function that takes the mass and volume of a block and calculates the density.|
# |Plotting | Use a Python library like Matplotlib to plot the mass vs. volume data for the four blocks and fit a line of best fit to determine the slope, which represents the density of the material. |

# %% [markdown]
# Let's start by importing the needed python libraries Numpy and Matplotlib (I like their documentation).

# %%
# %pip install matplotlib
# %conda install pandas
# %pip install numpy
# Out:
# Process pip requirements ...
#
# Requirement matplotlib already handled by conda/micromamba/mamba.
# Solving environment...
# Solving took 6.194800000000745 seconds
#   Name                          Version                       Build                         Channel
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ~ comm                          0.2.2 -> 0.2.3                pyhd8ed1ab_1 -> pyhe01879c_0  https://repo.prefix.dev/conda-forge -> https://repo.prefix.dev/conda-forge/
# ~ contourpy                     1.3.2 -> 1.3.3                py313h3a67976_0 -> py313h3a67976_1https://repo.prefix.dev/emscripten-forge-dev -> https://repo.prefix.dev/emscripten-forge-dev/
# ~ emscripten-abi                3.1.73 -> 3.1.73              h267e887_10 -> h267e887_12    https://repo.prefix.dev/emscripten-forge-dev -> https://repo.prefix.dev/emscripten-forge-dev/
# ...

# %%
import matplotlib as plt
import pandas as pd
import numpy as np
